# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Алгоритмы ХИИ/qm9.csv')

# %%
data = data.sample(n=20000, random_state=16)

# %%
data.shape
# Out:
# (20000, 17)

# %%
data.to_csv('/content/drive/MyDrive/Алгоритмы ХИИ/new_qm9.csv', index=False)
